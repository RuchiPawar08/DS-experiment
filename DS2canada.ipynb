# %%
import pandas as pd
import numpy as np
from sklearn import linear_model
import matplotlib.pyplot as plt
df = pd.read_csv('/content/canada.csv')
df.head()
# Out:
#    year  per capita income (US$)
# 0  1970              3399.299037
# 1  1971              3768.297935
# 2  1972              4251.175484
# 3  1973              4804.463248
# 4  1974              5576.514583

# %%
# %matplotlib inline
plt.xlabel('year')
plt.ylabel('per capita income (US$)')
plt.scatter(df.year,df['per capita income (US$)'],color='red',marker='*')

# Create and fit a linear regression model
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df['per capita income (US$)'])

plt.plot(df.year,reg.predict(df[['year']]),color='blue')

# %%
reg = linear_model.LinearRegression()
reg.fit(df[['year']], df['per capita income (US$)'])
# Out:
# LinearRegression()

# %%
y_pred=reg.predict(df[['year']])
y_pred=reg.predict(df[['year']])
df['predicted_year']=y_pred
df
# Out:
#     year  per capita income (US$)  predicted_year  predicted_income
# 0   1970              3399.299037     -134.559667       -134.559667
# 1   1971              3768.297935      693.905409        693.905409
# 2   1972              4251.175484     1522.370484       1522.370484
# 3   1973              4804.463248     2350.835559       2350.835559
# 4   1974              5576.514583     3179.300634       3179.300634
# 5   1975              5998.144346     4007.765709       4007.765709
# 6   1976              7062.131392     4836.230785       4836.230785
# 7   1977              7100.126170     5664.695860       5664.695860
# 8   1978              7247.967035     6493.160935       6493.160935
# 9   1979              7602.912681     7321.626010       7321.626010
# 10  1980              8355.968120     8150.091086       8150.091086
# 11  1981              9434.390652     8978.556161       8978.556161
# 12  1982              9619.438377     9807.021236       9807.021236
# 13  1983             10416.536590    10635.486311      10635.486311
# 14  1984             10790.328720    11463.951386      11463.951386
# 15  1985             11018.955850    12292.416462      12292.416462
# 16  1986             11482.891530    13120.881537      13120.881537
# 17  1987             12974.806620    13949.346612      13949.346612
# 18  1988             15080.283450    14777.811687      14777.811687
# 19  1989             16426.725480    15606.276763      15606.276763
# 20  1990             16838.673200    16434.741838      16434.741838
# 21  1991             17266.097690    17263.206913      17263.206913
# 22  1992             16412.083090    18091.671988      18091.671988
# 23  1993             15875.586730    18920.137063      18920.137063
# 24  1994             15755.820270    19748.602139      19748.602139
# 25  1995             16369.317250    20577.067214      20577.067214
# 26  1996             16699.826680    21405.532289      21405.532289
# 27  1997             17310.757750    22233.997364      22233.997364
# 28  1998             16622.671870    23062.462440      23062.462440
# 29  1999             17581.024140    23890.927515      23890.927515
# 30  2000             18987.382410    24719.392590      24719.392590
# 31  2001             18601.397240    25547.857665      25547.857665
# 32  2002             19232.175560    26376.322740      26376.322740
# 33  2003             22739.426280    27204.787816      27204.787816
# 34  2004             25719.147150    28033.252891      28033.252891
# 35  2005             29198.055690    28861.717966      28861.717966
# 36  2006             32738.262900    29690.183041      29690.183041
# 37  2007             36144.481220    30518.648117      30518.648117
# 38  2008             37446.486090    31347.113192      31347.113192
# 39  2009             32755.176820    32175.578267      32175.578267
# 40  2010             38420.522890    33004.043342      33004.043342
# 41  2011             42334.711210    33832.508417      33832.508417
# 42  2012             42665.255970    34660.973493      34660.973493
# 43  2013             42676.468370    35489.438568      35489.438568
# 44  2014             41039.893600    36317.903643      36317.903643
# 45  2015             35175.188980    37146.368718      37146.368718
# 46  2016             34229.193630    37974.833794      37974.833794
