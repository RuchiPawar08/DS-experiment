# %%
import pandas as pd
df = pd.read_csv("/content/email.csv")
df.head()
# Out:
#    Email_ID                                    Subject Contains_Link  \
# 0         1           Urgent: Verify your bank account           Yes
# 1         2             Meeting schedule for next week            No
# 2         3               Claim your lottery prize now           Yes
# 3         4  Invoice attached for your recent purchase            No
# 4         5     Security alert: Unusual login detected           Yes
#
#   Contains_Attachment Urgent_Words From_Trusted_Domain     Label
# 0                  No          Yes                  No  Phishing
# 1                  No           No                 Yes     Legit
# 2                  No          Yes                  No  Phishing
# 3                 Yes           No                 Yes     Legit
# 4                  No          Yes                  No  Phishing

# %%
df = pd.read_csv("/content/email.csv")
display(df.head())
display(df.info())
# Out:
#    Email_ID                                    Subject Contains_Link  \
# 0         1           Urgent: Verify your bank account           Yes
# 1         2             Meeting schedule for next week            No
# 2         3               Claim your lottery prize now           Yes
# 3         4  Invoice attached for your recent purchase            No
# 4         5     Security alert: Unusual login detected           Yes
#
#   Contains_Attachment Urgent_Words From_Trusted_Domain     Label
# 0                  No          Yes                  No  Phishing
# 1                  No           No                 Yes     Legit
# 2                  No          Yes                  No  Phishing
# 3                 Yes           No                 Yes     Legit
# 4                  No          Yes                  No  Phishing
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ...

# %%
df['Subject_Length'] = df['Subject'].apply(len)
df['Num_Links'] = df['Contains_Link'].apply(lambda x: 1 if x == 'Yes' else 0)
df['Num_Attachments'] = df['Contains_Attachment'].apply(lambda x: 1 if x == 'Yes' else 0)
df['Has_Urgent_Words'] = df['Urgent_Words'].apply(lambda x: 1 if x == 'Yes' else 0)
df['From_Trusted'] = df['From_Trusted_Domain'].apply(lambda x: 1 if x == 'Yes' else 0)
display(df.head())
# Out:
#    Email_ID                                    Subject Contains_Link  \
# 0         1           Urgent: Verify your bank account           Yes
# 1         2             Meeting schedule for next week            No
# 2         3               Claim your lottery prize now           Yes
# 3         4  Invoice attached for your recent purchase            No
# 4         5     Security alert: Unusual login detected           Yes
#
#   Contains_Attachment Urgent_Words From_Trusted_Domain     Label  \
# 0                  No          Yes                  No  Phishing
# 1                  No           No                 Yes     Legit
# 2                  No          Yes                  No  Phishing
# 3                 Yes           No                 Yes     Legit
# 4                  No          Yes                  No  Phishing
#
#    Subject_Length  Num_Links  Num_Attachments  Has_Urgent_Words  From_Trusted
# 0              32          1                0                 1             0
# ...

# %%
from sklearn.model_selection import train_test_split

X = df[['Subject_Length', 'Num_Links', 'Num_Attachments', 'Has_Urgent_Words', 'From_Trusted']]
y = df['Label'].map({'Legit': 0, 'Phishing': 1})

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

print("Shape of X_train:", X_train.shape)
print("Shape of X_test:", X_test.shape)
print("Shape of y_train:", y_train.shape)
print("Shape of y_test:", y_test.shape)
# Out:
# Shape of X_train: (11, 5)
# Shape of X_test: (4, 5)
# Shape of y_train: (11,)
# Shape of y_test: (4,)

# %%
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train,y_train)
# Out:
# GaussianNB()

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(GaussianNB(),X_train, y_train, cv=5)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_split.py:805: UserWarning: The least populated class in y has only 4 members, which is less than n_splits=5.
#   warnings.warn(
# array([1., 1., 1., 1., 1.])

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
X_test[0:10]
# Out:
#     Subject_Length  Num_Links  Num_Attachments  Has_Urgent_Words  From_Trusted
# 9               30          0                0                 0             1
# 11              35          0                1                 0             1
# 0               32          1                0                 1             0
# 13              38          0                0                 0             1

# %%
y_test[0:10]
# Out:
# 9     0
# 11    0
# 0     1
# 13    0
# Name: Label, dtype: int64

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
model.predict(X_test[0:10])
# Out:
# array([0, 0, 1, 0])

# %%
model.predict_proba(X_test[:10])
# Out:
# array([[1., 0.],
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]])

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred)

print(f"Accuracy: {accuracy:.4f}")
print(f"Precision: {precision:.4f}")
print(f"Recall: {recall:.4f}")
print(f"F1 Score: {f1:.4f}")
# Out:
# Accuracy: 1.0000
# Precision: 1.0000
# Recall: 1.0000
# F1 Score: 1.0000
